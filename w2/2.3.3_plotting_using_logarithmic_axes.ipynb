# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,10,20)
y1 = x**2.0
y2 = x**1.5
plt.loglog(x, y1, "bo-", linewidth=2, markersize=12, label="First");
plt.loglog(x, y2, "gs-", linewidth=2, markersize=12, label="Second");
plt.xlabel("$X$")
plt.ylabel("$Y$")
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc="upper left");
# Out:
# C:\Users\Aaron\anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Aaron\anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   # Remove the CWD from sys.path while we load stuff.

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.logspace(-1,1,40)
y1 = x**2.0
y2 = x**1.5
plt.loglog(x, y1, "bo-", linewidth=2, markersize=12, label="First");
plt.loglog(x, y2, "gs-", linewidth=2, markersize=12, label="Second");
plt.xlabel("$X$")
plt.ylabel("$Y$")
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc="upper left");
# Out:
# C:\Users\Aaron\anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Aaron\anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   # Remove the CWD from sys.path while we load stuff.

# %%
x = np.logspace(0,1,10)
y = x**2
plt.loglog(x,y,"bo-")
# A logarithmic plot that looks like a straight line with equal spacing
